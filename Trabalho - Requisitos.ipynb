# %% [markdown]
# # **Trabalho Final**
# ### Algoritmos e Programação com Linguagem Python
# ---
#
# **Orientações Gerais:**
#
# * Esta é o trabalho final prático onde serão trabalhados conceitos
# apresentados e exercitados em sala de aula.
#
# * Aspéctos como clareza e organização do código, comentários, raciocínio lógico, coerência no nome de variáveis, utilização das estruturas mais adequadas para a solução dos problemas e o funcionamento adequado serão analisados e irão compor o valor da nota final.
#
# * Procure entender exatamente o que se pede antes de iniciar a codificação. Quando se sabe o que é necessário fazer, a codificação fica mais fácil, mais eficiente e mais divertida ;-).
#
# * Faça o upload do notebook completo nomeado da seguinte forma: *nome_sobrenome_RA.ipynb*.
#
# * No caso de grupos, informar ao professor os membros de cada grupo e cada um deverá importar o arquivo no Canvas individualmente.
#
# * Arquivos com nomes incorretos serão desconsiderados!
#
# * Não deixem dúvidas para trás! Acessem os grupos combinados ou entrem em contato com o professor.
#
# ✌ Sucesso o/

# %% [markdown]
# # RMS Titanic
#
# O RMS Titanic foi um navio de passageiros britânico operado pela White Star Line e construído pelos estaleiros da Harland and Wolff em Belfast. Foi a segunda embarcação da Classe Olympic de transatlânticos depois do RMS Olympic e seguido pelo HMHS Britannic. Projetado pelos engenheiros navais Alexander Carlisle e Thomas Andrews, sua construção começou em março de 1909 e ele foi lançado ao mar em maio de 1911. O Titanic foi pensado para ser o navio mais luxuoso e mais seguro de sua época, gerando lendas que era supostamente "inafundável".
#
# A embarcação partiu em sua viagem inaugural de Southampton para Nova Iorque em 10 de abril de 1912, no caminho passando em Cherbourg-Octeville na França e por Queenstown na Irlanda. Ele colidiu com um iceberg às 23h40min do dia 14 de abril e afundou na madrugada do dia seguinte matando mais de 1500 pessoas, sendo um dos maiores desastres marítimos em tempos de paz de toda a história. Seu naufrágio destacou vários pontos fracos de seu projeto, deficiências nos procedimentos de evacuação de emergência e falhas nas regulamentações marítimas da época. Comissões de inquérito foram instauradas nos Estados Unidos e no Reino Unido, levando a mudanças nas leis internacionais de navegação que permanecem em vigor mais de um século depois.
#
# Os destroços do Titanic foram procurados por décadas até serem encontrados em 1985 por uma equipe liderada por Robert Ballard. Ele se encontra a 3843 m de profundidade e a 650 km ao sudeste de Terra Nova no Canadá. Sua história e naufrágio permaneceram no imaginário popular durante décadas, levando a produção de vários livros e filmes a seu respeito, mais notavelmente o filme Titanic de 1997. Até hoje o Titanic permanece como um dos navios mais famosos da história, com seus destroços atraindo várias expedições de exploração ao longo dos anos.
#
# *Fonte:* [WikiPedia](https://pt.wikipedia.org/wiki/RMS_Titanic)
#
# --------

# %% [markdown]
# A equipe da [Udacity](https://udacity.com) disponibilizou informações sobre uma parte dos passageiros à bordo do RMS Titanic no dia daquela tragédia. Esse _dataset_ que contém informações reais vem sendo utilizado em diversos estudos de caso, além de servir de base para aprendizado de Ciência de Dados, Estatística e Machine Learning.
#
# O arquivo **titanic_data.csv** contém informações reais sobre os passageiros organizadas da seguinte forma:
#
# - Survived (Sobreviveu): 0 = Não, 1 = Sim
# - Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# - Sex (Sexo): Sexo do passageiro
# - Age (Idade): Idade em anos
# - Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# - Parch: Quantidade de pais / crianças a bordo do Titanic
# - Ticket (Bilhete): Número do bilhete de embarque
# - Fare (Tarifa): Tarifa paga pelo Passageiro
# - Cabin (Cabine): Número de cabine
# - Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# O objetivo deste estudo é obter algumas informações estatísticas sobre a tragédia e realizar alguns _insights_ a respeito dos tripulantes e das circunstâncias do acidente.
#
# Efetue a carga do arquivo através da biblioteca _Pandas_ e a partir do _DataFrame_ gerado, efetue as operações necessárias para responder as questões.

# %% [markdown]
# ## Importando o DataSet

# %% [markdown]
# 1 - Efetuar a leitura do dataset através do Pandas, gerando um DataFrame de nome tit, levando-se em consideração que o arquivo encontra-se na mesma pasta do notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

dataset = pd.read_csv('titanic_data.csv')

# %% [markdown]
# ## Conhecendo o DataSet

# %% [markdown]
# 2 - Quantas linhas e colunas tem o dataset? Quais os tipos das colunas?

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 3 - Mostre os dados dos dez primeiros e 8 últimos registros do dataset.

# %%
dataset.head(10)
dataset.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %% [markdown]
# 4 - Cálculos envolvendo colunas numéricas com dados faltantes podem sofrer impacto. É possível afirmar se há dados faltantes no dataset? Caso positivo, quais e quantos seriam esses dados? Preencha os dados faltantes de forma que não influenciem em operações futuras.

# %%
print(dataset.isnull().sum())

valores_preenchimento = {
    'Age': np.random.randint(1,100),
    'Cabin': 0,
    'Embarked': 0,
}
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset_preenchido = dataset.fillna(value=valores_preenchimento)
dataset_preenchido
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Adequando o DataSet

# %% [markdown]
# 5 - Uma vez que algumas colunas não serão utilizadas, eventualmente é melhor excluí-las para que não interfiram na análise. Assim, exclua do dataset as colunas Sibsp, Parch e Ticket.

# %%
dataset_adequado = dataset_preenchido.drop(['SibSp', 'Parch', 'Ticket'], axis=1)
dataset_adequado
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %% [markdown]
# 6 - Renomear as colunas restantes para a lingua portuguesa, utilizando os seguintes nomes de colunas: IdPassageiro, Sobreviveu, Classe, Nome, Sexo, Idade, Tarifa, Cabine e Embarque.

# %%
novos_nomes = {
    'PassengerId': 'IdPassageiro', 
    'Survived': 'Sobreviveu',
    'Pclass': 'Classe',
    'Name': 'Nome',
    'Sex': 'Sexo',
    'Age': 'Idade',
    'Fare': 'Tarifa',
    'Cabin': 'Cabine',
    'Embarked': 'Embarque',
}

dataset_adequado = dataset_adequado.rename(columns=novos_nomes)
dataset_adequado
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 7 - Alterar o conteudo da coluna Sobreviveu para:
# - 0 => Não
# - 1 => Sim

# %%
coluna_sobreviveu = dataset_adequado['Sobreviveu']

def change_sobreviveu(x):
    if x == 0:
        x = 'Não'
    else:
        x = 'Sim'

    return x

nova_coluna_sobreviveu = coluna_sobreviveu.apply(change_sobreviveu)

dataset_adequado['Sobreviveu'] = nova_coluna_sobreviveu
dataset_adequado
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 8 - Alterar o conteudo da coluna Sexo para:
# - female => Mulher
# - male   => Homem

# %%
coluna_sexo= dataset_adequado['Sexo']

def change_sexo(x):
    if x == 'female':
        x = 'Mulher'
    else:
        x = 'Homem'

    return x

nova_coluna_sexo = coluna_sexo.apply(change_sexo)

dataset_adequado['Sexo'] = nova_coluna_sexo
dataset_adequado
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   Homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Mulher   38.0
# 2                               Heikkinen, Miss. Laina  Mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Mulher   35.0
# 4                             Allen, Mr. William Henry   Homem   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# ## Alguns números

# %% [markdown]
# 9 - Quantas mulheres e quantos homems estavam à bordo, de acordo com o dataset?

# %%
quantidade_H_M = dataset_adequado['Sexo'].value_counts()
quantidade_H_M
# Out:
# Homem     577
# Mulher    314
# Name: Sexo, dtype: int64

# %% [markdown]
# 10 - Quantos passageiros sobreviveram e quantos não sobreviveram?

# %%
quantidade_S_N = dataset_adequado['Sobreviveu'].value_counts()
quantidade_S_N
# Out:
# Não    549
# Sim    342
# Name: Sobreviveu, dtype: int64

# %% [markdown]
# 11 - Quantas mulheres não sobreviveram?

# %%
quantidade_M_N = dataset_adequado[
    (dataset_adequado['Sexo'] == 'Mulher') & (dataset_adequado['Sobreviveu'] == 'Não')
].shape[0]

quantidade_M_N
# Out:
# 81

# %% [markdown]
# 12 - Proporcionalmente, sobreviveram mais homens ou mais mulheres? Cite as proporções.

# %%
quantidade_M_S = dataset_adequado[
    (dataset_adequado['Sexo'] == 'Mulher') & (dataset_adequado['Sobreviveu'] == 'Sim')
].shape[0]

quantidade_H_S = dataset_adequado[
    (dataset_adequado['Sexo'] == 'Homem') & (dataset_adequado['Sobreviveu'] == 'Sim')
].shape[0]

total_passageiros = len(dataset_adequado[
    dataset_adequado['Sobreviveu'] == 'Sim'
])

porcentagem_M_S = quantidade_M_S/total_passageiros
porcentagem_H_S = quantidade_H_S/total_passageiros

print(f'Porcentagem dos homens que sobreviveram: {porcentagem_H_S: .2%}')
print(f'Porcentagem das mulheres que sobreviveram: {porcentagem_M_S: .2%}')
# Out:
# Porcentagem dos homens que sobreviveram:  31.87%
# Porcentagem das mulheres que sobreviveram:  68.13%

# %% [markdown]
# 13 - Levando-se em consideração a idade dos passageiros, qual a idade e quantidade de pessoas com o maior número de mortos?

# %%
numero_nao_sobreviventes_idade = dataset_adequado[
    (dataset_adequado['Sobreviveu'] == 'Não')
]['Idade'].value_counts()

print(f'Idade com maior número de mortos: {int(numero_nao_sobreviventes_idade.idxmax())}')
print(f'Número de mortos para a idade {int(numero_nao_sobreviventes_idade.idxmax())}: {numero_nao_sobreviventes_idade.max()}')
# Out:
# Idade com maior número de mortos: 8
# Número de mortos para a idade 8: 127

# %% [markdown]
# 14 - Qual a média de idade dos homens sobreviventes?

# %%
idade_media_homens = dataset_adequado[
    (dataset_adequado['Sexo'] == 'Homem') & (dataset_adequado['Sobreviveu'] == 'Sim')
]

idade_media_homens['Idade'].mean()
# Out:
# 24.44651376146789

# %% [markdown]
# 15 - Levando-se em consideração passageiros prioritários (mulheres e crianças de até 15 anos independente do sexo) qual a proporção de sobreviventes por sexo?

# %%
quan_pass_prioritarios_total = dataset_adequado[
    ((dataset_adequado['Idade'] <= 15) | (dataset_adequado['Sexo'] == 'Mulher')) & (dataset_adequado['Sobreviveu'] == 'Sim')
]

proporcao_sobreviventes = (quan_pass_prioritarios_total.groupby('Sexo')['Sobreviveu'].count())
proporcao_sobreviventes_homem = proporcao_sobreviventes[0]/len(quan_pass_prioritarios_total)
proporcao_sobreviventes_mulher = proporcao_sobreviventes[1]/len(quan_pass_prioritarios_total)

print(f'Porcentagem dos homens dos passageiros prioritários que sobreviveram: {proporcao_sobreviventes_homem: .2%}')
print(f'Porcentagem das mulheres que sobreviveram: {proporcao_sobreviventes_mulher: .2%}')
# Out:
# Porcentagem dos homens dos passageiros prioritários que sobreviveram:  13.70%
# Porcentagem das mulheres que sobreviveram:  86.30%

# %% [markdown]
# 16 - Qual a quantidade de passageiros por classe?

# %%
quantidade_passageiros_classe = dataset_adequado['Classe'].value_counts()
print(quantidade_passageiros_classe)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Classe, dtype: int64

# %% [markdown]
# 17 - Qual o percentual de sobreviventes por classe?

# %%
quantidade_sobreviventes_classe = dataset_adequado[
    (dataset_adequado['Sobreviveu'] == 'Sim')
]['Classe'].value_counts()

percentual_classe = []
for i in range(1,4):
    print(f'Percentual de sobreviventes da Classe {i}: {((quantidade_sobreviventes_classe[i])/(quantidade_passageiros_classe[i])): .2%}')
    percentual_classe.append((quantidade_sobreviventes_classe[i])/(quantidade_passageiros_classe[i]))

dict_porc_classe = {
    'Classe': ['Classe 1', 'Classe 2', 'Classe 3'],
    'Percentual': np.array(percentual_classe)*100,
}

porcentagem_classe_df = pd.DataFrame.from_dict(dict_porc_classe)

ax = porcentagem_classe_df.plot(kind='bar', xlabel='Classe', ylabel='Percentual de sobreviventes', title='Percentual de Sobreviventes por Classe')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(100))
ax.set_xticklabels(['Classe 1', 'Classe 2', 'Classe 3'])
for container in ax.containers:
    ax.bar_label(container, fmt='%1.2f%%')

print(quantidade_sobreviventes_classe/quantidade_passageiros_classe)
porcentagem_classe_df
# Out:
# Percentual de sobreviventes da Classe 1:  62.96%
# Percentual de sobreviventes da Classe 2:  47.28%
# Percentual de sobreviventes da Classe 3:  24.24%
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Classe, dtype: float64
#      Classe  Percentual
# 0  Classe 1   62.962963
# 1  Classe 2   47.282609
# 2  Classe 3   24.236253

# %% [markdown]
# 18 - Crie um dataframe que demonstre a quantidade de sobreviventes e não sobreviventes, agrupados por sexo e classe.

# %%
df_sobreviventes_classe_sexo = dataset_adequado.groupby(by=['Sexo', 'Classe'])['Sobreviveu'].apply(lambda x:( x=='Sim').sum())
df_n_sobreviventes_classe_sexo = dataset_adequado.groupby(by=['Sexo', 'Classe'])['Sobreviveu'].apply(lambda x: (x=='Não').sum())

df_agrupado = pd.DataFrame({'Sobreviventes': df_sobreviventes_classe_sexo, 'Não Sobreviventes': df_n_sobreviventes_classe_sexo})
print(df_agrupado)
ax = df_agrupado.plot(kind='bar', ylabel='Quantidade de Passageiros').set_xticklabels(['Homem e Classe 1', 'Homem e Classe 2', 'Homem e Classe 3','Mulher e Classe 1', 'Mulher e Classe 2', 'Mulher e Classe 3' ])
# Out:
#                Sobreviventes  Não Sobreviventes
# Sexo   Classe
# Homem  1                  45                 77
#        2                  17                 91
#        3                  47                300
# Mulher 1                  91                  3
#        2                  70                  6
#        3                  72                 72

# %% [markdown]
# 19 - Dos homens com idade entre 24 e 30 anos quantos da classe 3 sobreviveram? Quantos da classe 2 não sobreviveram?

# %%
quantidade_homens_24_30_classe_3 = dataset_adequado[
    (dataset_adequado['Idade']>24) & (dataset_adequado['Idade']<30) & ((dataset_adequado['Classe']==3)) & ((dataset_adequado['Sobreviveu']=='Sim')) & (dataset_adequado['Sexo']=='Homem')
].shape[0]

quantidade_homens_24_30_classe_2 = dataset_adequado[
    (dataset_adequado['Idade']>24) & (dataset_adequado['Idade']<30) & ((dataset_adequado['Classe']==2)) & ((dataset_adequado['Sobreviveu']=='Não')) & (dataset_adequado['Sexo']=='Homem')
].shape[0]

quantidade_homens_24_30_classe_3, quantidade_homens_24_30_classe_2
# Out:
# (10, 16)

# %% [markdown]
# 20 - Calcule a probabilidade condicional de uma pessoa sobreviver, dado seu sexo e a classe em que estava viajando:
# - P(S= true | G=female,C=1)
# - P(S= true | G=female,C=2)
# - P(S= true | G=female,C=3)
# - P(S= true | G=male,C=1)
# - P(S= true | G=male,C=2)
# - P(S= true | G=male,C=3)

# %%
def P(genero, classe):
    df_classe_sexo = dataset_adequado.groupby(['Sexo', 'Classe']).size()
    df_classe_sexo_sobreviventes = dataset_adequado[
        (dataset_adequado['Sobreviveu'] == 'Sim')
    ].groupby(['Sexo', 'Classe']).size()

    probabilidade_cond = df_classe_sexo_sobreviventes[genero][classe]/df_classe_sexo[genero][classe]
    ax = (df_classe_sexo_sobreviventes/df_classe_sexo).plot(kind='bar', ylabel='Probabilidade Condicional de Sobrevivência')
    ax.set_title('Probabilidade Condicional de Sobrevivência por Sexo e Classe')
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    ax.set_xticklabels(['Homem e Classe 1', 'Homem e Classe 2', 'Homem e Classe 3','Mulher e Classe 1', 'Mulher e Classe 2', 'Mulher e Classe 3'])

    return '{:,.2%}'.format(probabilidade_cond)

P('Mulher', 1)
# Out:
# '96.81%'

# %%
df_classe_sexo = dataset_adequado.groupby(['Sexo', 'Classe']).size()
df_classe_sexo_sobreviventes = dataset_adequado[
    (dataset_adequado['Sobreviveu'] == 'Sim')
].groupby(['Sexo', 'Classe']).size()

ax = (df_classe_sexo_sobreviventes/df_classe_sexo).plot(kind='bar', ylabel='Probabilidade Condicional de Sobrevivência')
ax.set_title('Probabilidade Condicional de Sobrevivência por Sexo e Classe')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.set_xlabel('Sexo e Classe')
ax.set_xticklabels(['Homem e Classe 1', 'Homem e Classe 2', 'Homem e Classe 3','Mulher e Classe 1', 'Mulher e Classe 2', 'Mulher e Classe 3' ])
print(df_classe_sexo_sobreviventes/df_classe_sexo)
# Out:
# Sexo    Classe
# Homem   1         0.368852
#         2         0.157407
#         3         0.135447
# Mulher  1         0.968085
#         2         0.921053
#         3         0.500000
# dtype: float64

# %%
dataset_adequado.to_csv('novo_titanic_data.csv', index=False)
